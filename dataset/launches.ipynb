# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('Launches.json')

# %%
df.head(5)
# Out:
#                                      id  \
# 0  cf0a0e4c-ce72-4b50-af07-016326cbceff
# 1  30412a48-cb4d-43d6-a304-6ae5f062504f
# 2  b48423e2-ba38-46d4-88bb-45cdbb6d74a5
# 3  f8a96988-9ba4-4480-84c4-496492e67e23
# 4  3637c9eb-25b4-4aaa-bb7e-2c3c53c46e56
#
#                                                  url  \
# 0  https://lldev.thespacedevs.com/2.2.0/launch/cf...
# 1  https://lldev.thespacedevs.com/2.2.0/launch/30...
# 2  https://lldev.thespacedevs.com/2.2.0/launch/b4...
# 3  https://lldev.thespacedevs.com/2.2.0/launch/f8...
# 4  https://lldev.thespacedevs.com/2.2.0/launch/36...
#
#                        slug flightclub_url r_spacex_api_id  \
# 0   long-march-7-tianzhou-3           None            None
# 1   kuaizhou-1a-jilin-1-02d           None            None
# 2  long-march-3be-shiyan-10           None            None
# 3     atlas-v-401-landsat-9           None            None
# 4     soyuz-21a-soyuz-ms-19           None            None
#
#                           name  \
# ...
